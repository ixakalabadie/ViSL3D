# %%
import sys
sys.path.append('..\\')

# %%
from visl3d import visual as vis

# %% [markdown]
# ViSL3D includes the possibility of displaying the visualisations within Jupyter Notebooks in addition to doing it in a browser.<br>
# First, we create Cube object the same way as shown in other [example notebooks](https://github.com/ixakalabadie/ViSL3D/blob/master/example/general_example.ipynb).<br>
# Then, we run *createVis* but we must set the *notebook* atribute to True. This will create a temporary file that will be opened to visualise it in the cell and removed immediately afterwards.<br>
# This way, we can interact with the 3D model directly without needing other software.

# %%
cube = vis.prep_one('..\\..\\NGC2997_CUBE.fits', lims=[[300,-200],[200,200],[0,-1]], unit='rms')
cube.resol=3
vis.createVis(cube, 'hcg16', notebook=True)
# Out:
# ...
# C:\Users\ixaka\miniconda3\envs\x3d\lib\site-packages\scipy\stats\_continuous_distns.py:419: RuntimeWarning: Mean of empty slice.
#   loc = data.mean()
# C:\Users\ixaka\miniconda3\envs\x3d\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\ixaka\miniconda3\envs\x3d\lib\site-packages\scipy\stats\_continuous_distns.py:424: RuntimeWarning: Mean of empty slice.
#   scale = np.sqrt(((data - loc)**2).mean())
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 cube = vis.prep_one('..\\..\\NGC2997_CUBE.fits', lims=[[200,-200],[200,-200],[0,-1]], unit='rms')
#       2 cube.resol=3
#       3 vis.createVis(cube, 'hcg16', notebook=True)
#
# ...

# %% [markdown]
# ![Full ipyViSL3D visualisation](https://raw.githubusercontent.com/ixakalabadie/ixakalabadie.github.io/master/visualisations/ipyViSL3D_buttons.png)

# %% [markdown]
# ViSL3D also allows displaying previously created (and saved) files in notebooks.<br>
# To do that, we just have to input the name of the HTML file we want to visualise to the *displayVis* function as in the example below.

# %%
vis.displayVis('hcg16_example.html')

# %% [markdown]
# ![Minimal ipyViSL3D visualisation](https://raw.githubusercontent.com/ixakalabadie/ixakalabadie.github.io/master/visualisations/ipyViSL3D_minimal.png)
